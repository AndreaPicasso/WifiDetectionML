# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(context="paper", font="monospace")

import sys
print(sys.version)

# %matplotlib inline
# Out:
# 3.6.1 |Anaconda 4.4.0 (64-bit)| (default, May 11 2017, 13:25:24) [MSC v.1900 64 bit (AMD64)]

# %%
df = pd.read_csv('MIE_resources/trainingset.csv')

# %%
pd.set_option('display.max_columns', None)
df.columns = ['id', 'Time', 'mac', 'power', 'sequence', 'SSID', 'suppRates', 'ExtSuppRates','HTCapabilitiesInfo', 'AMPDU', 'HTExtendendCapabilities', 'orderedTagList', 'formattingCapabilities', 'channel', 'UUID-E', 'primaryDevice', 'model', 'modelNumber', 'deviceName', 'vendorExtention', 'vendorId', 'OUI']
df.head(4)
# Out:
#     id                           Time                mac  power  sequence  \
# 0    3  2017-07-12 12:21:04.643966109  98:9e:63:51:e5:d8    -92      1911
# 1  728  2017-07-12 12:21:12.642847667  84:2e:27:fb:22:a3    -88      3487
# 2  732  2017-07-12 12:21:12.672652811  84:2e:27:fb:22:a3    -95      3488
# 3  797  2017-07-12 12:21:13.436520417  d0:23:db:d0:ec:88    -89      2989
#
#       SSID   suppRates           ExtSuppRates HTCapabilitiesInfo AMPDU  \
# 0  eduroam  1,2,5.5,11  6,9,12,18,24,36,48,54             0x0021  0x17
# 1      NaN  1,2,5.5,11  6,9,12,18,24,36,48,54             0x012c  0x03
# 2      NaN  1,2,5.5,11  6,9,12,18,24,36,48,54             0x012c  0x03
# 3      NaN  1,2,5.5,11  6,9,12,18,24,36,48,54             0x1800  0x1b
#
#   HTExtendendCapabilities                                     orderedTagList  \
# 0                  0x0000  SSID parameter set,Supported Rates,Extended Su...
# 1                  0x0000  SSID parameter set,Supported Rates,Extended Su...
# ...

# %%
df.isnull().sum()
# Out:
# id                            0
# Time                          0
# mac                           0
# power                         0
# sequence                      0
# SSID                       1096
# suppRates                     0
# ExtSuppRates                 18
# HTCapabilitiesInfo          222
# AMPDU                       222
# HTExtendendCapabilities     222
# orderedTagList                0
# formattingCapabilities     1126
# channel                       0
# UUID-E                     1768
# primaryDevice              1768
# model                      1768
# modelNumber                1768
# deviceName                 1768
# vendorExtention            1768
# vendorId                   1768
# OUI                         393
# dtype: int64

# %%
df.describe()
# Out:
#                   id        power     sequence  channel  vendorId
# count    1828.000000  1828.000000  1828.000000   1828.0      60.0
# mean    77619.931072   -74.659190  1765.285558      1.0   14122.0
# std     44071.114654    15.703755  1181.917714      0.0       0.0
# min         3.000000  -100.000000     0.000000      1.0   14122.0
# 25%     41036.500000   -87.000000   683.000000      1.0   14122.0
# 50%     77198.500000   -78.000000  1710.500000      1.0   14122.0
# 75%    115850.750000   -66.000000  2816.750000      1.0   14122.0
# max    156761.000000   -29.000000  4094.000000      1.0   14122.0

# %%
# Correlazione tra i vari attributi

#
# Problema: non lo fa di tutti i valori, se un valore è stringa allora df.corr non funziona, bisognerebbe convertirlo
# Direi che non serve a nulla...

#corrmat = df.corr()
#f, ax = plt.subplots(figsize=(12, 9))
#sns.heatmap(corrmat, vmax=.8, square=True)

# %%
mac_diff = df.groupby('mac').id.nunique()
mac_diff.describe()
#
# NEL TESTSET (Quello attuale è il training)
# 51 mac diversi, nel nostro conteggio sono presenti 46 persone
# ogni mac invia mediamente 8 probe, con un minimo di 1 ed un massimo di 66
# in realtà però il 25%quantile è 2 perciò il 25% delle persone hanno inviato solo 1-2 probe
# Out:
# count    129.000000
# mean      14.170543
# std       41.790236
# min        1.000000
# 25%        2.000000
# 50%        4.000000
# 75%       13.000000
# max      433.000000
# Name: id, dtype: float64

# %%
mac_diff.hist(figsize=(10, 10))

# %%
df.hist(figsize=(20, 20))

# Come si fa a vedere anche gli altri campi?
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000025F104419B0>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000025F105D9F28>]], dtype=object)

# %%
# Lista dei Mac noti
# I mac non randomizzati si possono distinguere da quelli reali considerando se è un mac associato ad un'azienda
# I mac non possono essere randomizzati usando mac appartenenti a range posseduti da aziende, in quanto potrebbero
# esistere device con quel mac     DIREI
#
# Inoltre riusciamo ad aggiungere ai pacchetti un informazione che può essere non banale: il vendor

mac_vendor = pd.read_csv('MIE_resources/mac_address_vendor.csv')

# %%
for i in range(0, len(mac_vendor)):
    mac_vendor.loc[i, 'prefix'] = mac_vendor.prefix[i][0:2].lower()+":"+mac_vendor.prefix[i][2:4].lower()+":"+mac_vendor.prefix[i][4:6].lower()
mac_vendor.head(10)
# Out:
#    Unnamed: 0                                        companyName country  \
# 0           0               Shenzhen ViewAt Technology Co.,Ltd.       CN
# 1           1  Integrated Device Technology (Malaysia) Sdn. Bhd.      MY
# 2           2                                            NETGEAR      US
# 3           3                                    Hewlett Packard      US
# 4           4                                    Hewlett Packard      US
# 5           5                                    Hewlett Packard      US
# 6           6                                    Hewlett Packard      US
# 7           7                              Cognitec Systems GmbH      DE
# 8           8                                 D-Link Corporation      TW
# 9           9                                 D-Link Corporation      TW
#
#      prefix streetAddress1 streetAddress2
# 0  e0:43:db            NaN            NaN
# 1  24:05:f5            NaN            NaN
# ...

# %%
#df.insert(3, 'vendor', ['']*len(df))
for i in range(0, len(df)):
    vendor = mac_vendor.loc[mac_vendor['prefix'] == df.loc[i, 'mac'][0:8]].companyName.tolist()
    if(len(vendor)>0):
        df.loc[i, 'vendor'] = vendor[0]

# %%
df.head()
# Out:
#      id                           Time                mac  power  sequence  \
# 0     3  2017-07-12 12:21:04.643966109  98:9e:63:51:e5:d8    -92      1911
# 1   728  2017-07-12 12:21:12.642847667  84:2e:27:fb:22:a3    -88      3487
# 2   732  2017-07-12 12:21:12.672652811  84:2e:27:fb:22:a3    -95      3488
# 3   797  2017-07-12 12:21:13.436520417  d0:23:db:d0:ec:88    -89      2989
# 4  1107  2017-07-12 12:21:16.989734405  40:0e:85:35:d1:db    -71      2781
#
#       SSID   suppRates           ExtSuppRates HTCapabilitiesInfo AMPDU  \
# 0  eduroam  1,2,5.5,11  6,9,12,18,24,36,48,54             0x0021  0x17
# 1      NaN  1,2,5.5,11  6,9,12,18,24,36,48,54             0x012c  0x03
# 2      NaN  1,2,5.5,11  6,9,12,18,24,36,48,54             0x012c  0x03
# 3      NaN  1,2,5.5,11  6,9,12,18,24,36,48,54             0x1800  0x1b
# 4  Papilio  1,2,5.5,11  6,9,12,18,24,36,48,54             0x102d  0x17
#
#   HTExtendendCapabilities                                     orderedTagList  \
# ...

# %%
#mac_randomizzati = df.loc[df['vendor'].isnull()]
#mac_randomizzati.count()

# %%
# Verifichiamo "statisticamente" se è vera l'ipotesi che le HT capab inviate sono sempre le stesse
for mac in mac_diff.keys():
    probes = df.loc[df['mac'] == mac]
    probes.fillna(value=999999, inplace=True)
    print("\n\n"+mac)
    print("diverse suppRates:", len(probes.loc[probes['suppRates'] != probes.suppRates.tolist()[0] ]))
    print("diverse ExtsuppRates:", len(probes.loc[probes['ExtSuppRates'] != probes.ExtSuppRates.tolist()[0]]))
    print("diverse HTCapabilitiesInfo:", len(probes.loc[probes['HTCapabilitiesInfo'] != probes.HTCapabilitiesInfo.tolist()[0]]))
    print("diverse AMPDU:", len(probes.loc[probes['AMPDU'] != probes.AMPDU.tolist()[0]]))
    print("diverse HTExtendendCapabilities:", len(probes.loc[probes['HTExtendendCapabilities'] != probes.HTExtendendCapabilities.tolist()[0]]))
    print("diverse orderedTagList:", len(probes.loc[probes['orderedTagList'] != probes.orderedTagList.tolist()[0]]))
    print("diverse formattingCapabilities:", len(probes.loc[probes['formattingCapabilities'] != probes.formattingCapabilities.tolist()[0]]))
    print("diverse primaryDevice:", len(probes.loc[probes['primaryDevice'] != probes.primaryDevice.tolist()[0]]))
    print("diverse model:", len(probes.loc[probes['model'] != probes.model.tolist()[0]]))
    print("diverse modelNumber:", len(probes.loc[probes['modelNumber'] != probes.modelNumber.tolist()[0]]))
    print("diverse deviceName:", len(probes.loc[probes['deviceName'] != probes.deviceName.tolist()[0]]))
    print("diverse vendorExtention:", len(probes.loc[probes['vendorExtention'] != probes.vendorExtention.tolist()[0]]))
    print("diverse vendorId:", len(probes.loc[probes['vendorId'] != probes.vendorId.tolist()[0]]))
    print("diverse OUI:", len(probes.loc[probes['OUI'] != probes.OUI.tolist()[0]]))
# Out:
# C:\Users\simone\Anaconda3\lib\site-packages\pandas\core\frame.py:2852: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   downcast=downcast, **kwargs)
# 00:25:d3:84:72:27
# diverse suppRates: 0
# diverse ExtsuppRates: 0
# diverse HTCapabilitiesInfo: 0
# diverse AMPDU: 0
# diverse HTExtendendCapabilities: 0
# diverse orderedTagList: 0
# diverse formattingCapabilities: 0
# diverse primaryDevice: 0
# diverse model: 0
# diverse modelNumber: 0
# diverse deviceName: 0
# diverse vendorExtention: 0
# diverse vendorId: 0
# diverse OUI: 0
#
#
# 08:3d:88:44:2a:ed
# diverse suppRates: 0
# diverse ExtsuppRates: 0
# diverse HTCapabilitiesInfo: 0
# diverse AMPDU: 0
# diverse HTExtendendCapabilities: 0
# diverse orderedTagList: 0
# diverse formattingCapabilities: 0
# diverse primaryDevice: 0
# diverse model: 0
# ...

# %%
#
# Come possiamo notare, tranne alcuni casi ritenuti trascurabili, un device invia sempre gli stessi valori dei campi
# HT capabilities
# Ciò che potrebbe succedere (tranne per 1 caso "patologico" che invia suppRates diverse)
# è che in alcune probe request mancano alcuni dati presenti in altre probe provenienti dallo stesso mac
#
# Può essere perciò opportuno non basare il calcolo della distanza sui missing data ma solamente su valori non nulli
# es. 
# dist(i, j){
#    ....
#    if(!Aj.isnull() && !Ai.isnull() && Ai == Aj) return 0
#}
# NOTA: ciò viene fatto in automatico, si potrebbe scivere direttamente #    if(Ai == Aj) return 0
# in quanto in python due valori NaN NON SONO UGUALI
#    (vedi sotto)



df.loc[df['mac'] == '40:f3:08:3a:f3:c1']
#8c:79:67:82:33:a1
# Out:
#           id                           Time                mac  power  \
# 674    58134  2017-07-12 12:30:34.701411334  40:f3:08:3a:f3:c1    -91
# 675    58138  2017-07-12 12:30:34.721896695  40:f3:08:3a:f3:c1    -96
# 715    60510  2017-07-12 12:30:59.816107013  40:f3:08:3a:f3:c1    -94
# 1304  108465  2017-07-12 12:39:01.637527932  40:f3:08:3a:f3:c1    -89
# 1576  136122  2017-07-12 12:41:54.063192023  40:f3:08:3a:f3:c1    -92
# 1577  136126  2017-07-12 12:41:54.083628218  40:f3:08:3a:f3:c1    -91
# 1583  137258  2017-07-12 12:42:05.902767592  40:f3:08:3a:f3:c1    -68
# 1584  137265  2017-07-12 12:42:05.922877566  40:f3:08:3a:f3:c1    -71
# 1599  138241  2017-07-12 12:42:16.198626975  40:f3:08:3a:f3:c1    -83
# 1600  138246  2017-07-12 12:42:16.219016655  40:f3:08:3a:f3:c1    -84
# 1601  138342  2017-07-12 12:42:17.344261326  40:f3:08:3a:f3:c1    -85
# 1602  138345  2017-07-12 12:42:17.364689683  40:f3:08:3a:f3:c1    -87
# ...

# %%
print(df.HTCapabilitiesInfo[18])
print(df.HTCapabilitiesInfo[1725])
print(df.HTCapabilitiesInfo[18] == df.HTCapabilitiesInfo[1725])
# Out:
# nan
# nan
# False

# %%
# Out:
# False

# %%
# Out:
# nan

# %%
#from scipy.cluster.hierarchy import dendrogram, linkage
#Z = linkage(df, 'ward')
