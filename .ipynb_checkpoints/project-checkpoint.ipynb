# %%
# TODO: caricare Database completo

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(context="paper", font="monospace")

import sys
print(sys.version)

# %matplotlib inline
# Out:
# 3.6.1 |Anaconda 4.4.0 (64-bit)| (default, May 11 2017, 13:25:24) [MSC v.1900 64 bit (AMD64)]

# %%
#Dialogo direttamente con il databaas
import MySQLdb
db = MySQLdb.connect(host="localhost",    # your host, usually localhost
                     user="root",         # your username
                     passwd="",  # your password
                     db="densita_popolazione")

# %%
df = pd.read_sql('SELECT * FROM sniff', con=db)

# %%
df.head(4)
# Out:
#    id                mac mac_num  locally  pow                data  chan  \
# 0   2  78:25:ad:11:67:af    None        8  -86 2017-04-27 19:45:30    10
# 1   3  78:25:ad:11:67:af    None        8  -86 2017-04-27 19:45:31    10
# 2   4  18:4f:32:f2:e7:81    None        8  -77 2017-04-27 19:45:31    11
# 3   5  18:4f:32:f2:e7:81    None        8  -82 2017-04-27 19:45:31    11
#
#     seq      ht_cap    ht_ampdu  ...                 mcs_1_7  \
# 0   321                          ...
# 1   347                          ...
# 2  1187  0x0000182d  0x00000017  ...    0x000000ff,0x000000f
# 3  1188  0x0000182d  0x00000017  ...    0x000000ff,0x000000f
#
#                mcs_8_15             mcs_16_23             mcs_24_31  \
# 0
# 1
# 2  0x000000ff,0x000000f  0x00000000,0x0000000  0x00000000,0x0000000
# 3  0x000000ff,0x000000f  0x00000000,0x0000000  0x00000000,0x0000000
#
#                  mcs_32             mcs_33_38             mcs_39_52  \
# 0
# 1
# 2  0x00000000,0x0000000  0x00000000,0x0000000  0x00000000,0x0000000
# 3  0x00000000,0x0000000  0x00000000,0x0000000  0x00000000,0x0000000
#
#               mcs_53_76          ssid uuid_e
# 0                        SAMSUNGSMART
# 1                        SAMSUNGSMART
# 2  0x00000000,0x0000000
# 3  0x00000000,0x0000000
#
# [4 rows x 23 columns]

# %%
# Vediamo quanti valori nulli ci sono
# Un valore nullo per noi non rappresenta propriamente la "mancanza di un'informazione" ma bensì anche essa entrerà a far parte
# della firma per identificare una persona, in quanto significa che quel particolare telefono non invia quel valore CREDO

# Cosa possiamo fare con i missing data? Dobbiamo riempirli?

df = df.replace('', np.nan, regex=True)

df.isnull().sum()
# Out:
# id                    0
# mac                   0
# mac_num          126425
# locally               0
# pow                   0
# data                  0
# chan                  0
# seq                   0
# ht_cap            31301
# ht_ampdu          31301
# vht_cap          123858
# sup_rates            46
# ext_sup_rates       243
# mcs_1_7           31301
# mcs_8_15          31301
# mcs_16_23         31301
# mcs_24_31         31301
# mcs_32            31301
# mcs_33_38         31301
# mcs_39_52         31301
# mcs_53_76         31301
# ssid              49418
# uuid_e           125162
# dtype: int64

# %%
df.describe()
# Out:
#                   id        locally            pow           chan  \
# count  126425.000000  126425.000000  126425.000000  126425.000000
# mean    63222.751987       6.174206     -79.309393       6.166470
# std     36498.010239       3.651282      11.808395       3.164424
# min         2.000000       0.000000     -92.000000       1.000000
# 25%     31614.000000       4.000000     -87.000000       4.000000
# 50%     63223.000000       8.000000     -86.000000       6.000000
# 75%     94831.000000       8.000000     -70.000000       9.000000
# max    126437.000000      14.000000     -38.000000      13.000000
#
#                  seq
# count  126425.000000
# mean     1718.358110
# std      1270.464081
# min         0.000000
# 25%       444.000000
# 50%      1591.000000
# 75%      2834.000000
# max      4095.000000

# %%
# Correlazione tra i vari attributi

corrmat = df.corr()
f, ax = plt.subplots(figsize=(12, 9))
sns.heatmap(corrmat, vmax=.8, square=True)
